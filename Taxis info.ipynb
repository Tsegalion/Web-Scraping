# %%
from bs4 import BeautifulSoup
import time
from selenium import webdriver
import pandas as pd

def scrape_yell_data(url):
    driver = webdriver.Chrome(r"C:\Users\Tsega\Downloads\chromedriver-win64\chromedriver.exe")
    driver.get(url)
    time.sleep(20)

    # Scrolling to the bottom of the page to load all the content
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(5)

    # Extract the page source
    page_source = driver.page_source
    soup = BeautifulSoup(page_source, 'html.parser')

    container = soup.find('div', class_='col-sm-24 col-md-17 col-lg-17 results--rightNav')

    cabs = container.find_all('article', class_=lambda x: x and x.startswith('col-sm-24 businessCapsule businessCapsule-'))

    return cabs

def extract_data(cab):
    try:
        name = cab.find('h2', class_='businessCapsule--name text-h2').text.strip()
    except AttributeError:
        name = 'N/A'
    
    try:
        phone = cab.find('div', class_='business--telephoneContent').text.strip()
    except AttributeError:
        phone = 'N/A'
    
    try:
        web = cab.find('div', class_='col-sm-24 businessCapsule--ctas')
        links = web.find_all('a', href=True)
        website = [link['href'] for link in links]
    except AttributeError:
        website = 'N/A'

    try:
        rating = cab.find('span', class_='starRating--average').text
    except AttributeError:
        rating = 0

    return {
        'Name': name,
        'Phone': phone,
        'Website': website,
        'Rating': rating
    }

def main():
    url = 'https://www.yell.com/ucs/UcsSearchAction.do?keywords=Taxis+%26+Private+Hire+Vehicles&location=ledbury&scrambleSeed=1738547925&pageNum='
    
    # Using list comprehension to create the data list
    data = [extract_data(cab) for x in range(1, 3) for cab in scrape_yell_data(url + str(x))]

    # Creating the DataFrame directly from the data list
    df = pd.DataFrame(data)
    # print(df)
    df.to_csv('yell_data.csv', index=False)

if __name__ == "__main__":
    main()
# Out:
#                                               Name                   Phone
# 0                                       Bizzy Cars  Hereford\n01432 807069  \
# 1                               G & T Private Hire       Tel\n07922 126136
# 2                              Filip Umurski Taxis       Tel\n07903 112849
# 3                          Somerville Private Hire       Tel\n07854 223950
# 4                                        VSP Taxis       Tel\n07515 496590
# 5                         Ledbury Private Car Hire       Tel\n07976 288140
# 6                             Ledbury Taxi Service       Tel\n01531 633596
# 7                              Apollo Airport Cars       Tel\n01684 564442
# 8                                      Daves Taxis       Tel\n01989 554004
# 9                                      Smith Taxis       Tel\n01684 210687
# 10                         Malvern Taxis Minibuses       Tel\n07502 020808
# 11                                     Karl's Taxi       Tel\n01432 381234
# 12                                  Colwell Cabbie       Tel\n01684 540717
# 13                             Great Malvern Taxis       Tel\n01684 561117
# 14         MET - Malvern Taxis & Airport Transfers       Tel\n07399 325007
# 15                                    B N S Travel       Tel\n07511 128174
# 16                         Speedline Malvern Taxis       Tel\n07955 220082
# 17                              Syed Malvern Taxis       Tel\n01684 800123
# 18                            Apollo Mercedes Cars       Tel\n01684 891902
# 19                               Ras Malvern Taxis       Tel\n01684 560221
# 20                         M & M Cars Private Hire       Tel\n07702 740155
# 21                                       J R Taxis       Tel\n01684 899131
# 22                                    B & S Travel       Tel\n07511 128174
# 23                                      A & A Taxi       Tel\n07511 128174
# 24                                     Alpha Taxis       Tel\n07411 976464
# 25                                 Fabcabs Malvern       Tel\n07940 224451
# 26                                    B S N Travel       Tel\n07511 128174
# 27                                  Autocabs Taxis       Tel\n01684 566836
# 28                                    Access Taxis       Tel\n07749 621594
# 29                                    Malvern Cabs       Tel\n07511 128174
# 30                                    Malvern Cabs       Tel\n07498 543252
# 31                             Ramies Taxi Malvern       Tel\n01684 438042
# 32  Art Malvern Taxis Within Great Malvern Station       Tel\n07730 573738
# 33                          Xpress Cars Tewkesbury       Tel\n01684 216216
# 34                                GSA Private Hire       Tel\n01989 567951
# 35                                  Welland Wheels       Tel\n07956 043760
# 36                              Taxis Malvern Link       Tel\n07939 427526
# 37                                   Orbital Taxis       Tel\n01684 899100
# 38                                 William's Taxis       Tel\n01684 577994
# 39                                   Naj Taxi Hire       Tel\n01684 578749
# 40                           Malvern Permier Taxis       Tel\n01684 880900
# 41                                        KTM Cars       Tel\n01684 576646
# 42                               Jak Malvern Taxis       Tel\n07460 883203
# 43                                      Krazy Kabs       Tel\n01684 577774
# 44                                      Shell Cabs       Tel\n01684 891414
# 45                                  Hillside Taxis       Tel\n07478 627772
# 46                                    AA Taxis Ltd       Tel\n01684 891414
# 47                                   Malvern Taxis       Tel\n01684 572020
# 48             Bromyard & Tenbury Taxis & Couriers       Tel\n01885 482111
# 49                                        Albiecab       Tel\n07588 715240
#
#                                               Website Rating
# 0   [/customerneeds/sendenquiry/sendtoone/10004038...      0
# 1                                                  []    5.0
# 2                                                  []    5.0
# 3           [http://www.somervilleprivatehire.co.uk/]    5.0
# 4                                                  []      0
# 5                 [http://www.ledburyprivatehire.com]    4.0
# 6                                                  []      0
# 7                       [http://www.malverntaxis.org]    5.0
# 8   [/customerneeds/sendenquiry/sendtoone/10000895...    5.0
# 9                       [http://www.smithtaxis.co.uk]    5.0
# 10  [https://www.facebook.com/malvern-taxis-minibu...    2.3
# 11  [https://karlstaxi.co.uk/?utm_source=yell&utm_...    4.6
# 12                                                 []    5.0
# 13    [http://www.airporttransfersgreatmalvern.co.uk]      0
# 14                          [http://www.met-cars.com]    5.0
# 15                       [http://www.bnstravel.co.uk]    5.0
# 16               [http://www.taxisgreatmalvern.co.uk]    5.0
# 17                 [http://www.syedmalverntaxis.com ]    4.6
# 18                                                 []      0
# 19                                                 []    5.0
# 20  [http://www.mmprivatehire.co.uk?utm_source=yel...    5.0
# 21                                                 []    5.0
# 22                                                 []    5.0
# 23                      [http://www.bnstravel.co.uk/]    5.0
# 24                                                 []    5.0
# 25        [http://www.airporttransfersmalvern.co.uk/]      0
# 26                                                 []    5.0
# 27                                                 []    5.0
# 28                      [http://www.malverntaxis.com]    5.0
# 29                       [http://www.bnstravel.co.uk]    5.0
# 30                                                 []    5.0
# 31                      [http://www.ramiestaxi.co.uk]    5.0
# 32                    [http://art-malverntaxi.co.uk/]    5.0
# 33              [https://xpresscarstewkesbury.co.uk/]    5.0
# 34                    [http://www.gsaprivatehire.com]    5.0
# 35                      [https://wellandwheels.co.uk]      0
# 36                 [http://www.syedmalverntaxis.com ]    3.5
# 37                                                 []      0
# 38                                                 []      0
# 39                             [http://najtaxi.co.uk]    1.0
# 40                                                 []      0
# 41                                                 []      0
# 42                    [http://jak-malverntaxis.co.uk]      0
# 43                                                 []      0
# 44                                                 []    3.7
# 45                                                 []      0
# 46                                                 []      0
# 47                                                 []      0
# 48                   [http://www.bromyardtaxis.co.uk]    5.0
# 49                                                 []      0
